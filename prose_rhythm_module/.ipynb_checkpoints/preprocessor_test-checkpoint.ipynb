# %% [markdown]
# # Test Preprocessor Module #

# %% [markdown]
# Import preprocessor class.

# %%
from preprocessor import Preprocessor

# %% [markdown]
# Instantiate class with text and punctuation parameters.

# %%
test_text = "Galliā est omnīs dīvīsa in partēs trēs quārum ūnam incolunt Belgae aliam Aquītānī tertiam quī ipsōrum lingua Celtae nostra Gallī appellantur. hī omnēs linguā īnstitūtīs lēgibus inter sē differunt. Gallōs ab Aquītānīs Garunna flūmen ā Belgīs Matrona et Sēquana dīvidit. hōrum omnium fortissimī sunt Belgae proptereā quod ā cultū atque hūmānitāte prōvinciae longissimē absunt minimēque ad eōs mercātōrēs saepe commeant atque ea quae ad effēminandōs animōs pertinent important proximīque sunt Germānīs quī trāns Rhēnum incolunt quibuscum continenter bellum gerunt. quā dē causā Helvētiī quoque reliquōs Gallōs virtūte praecēdunt quod ferē cotīdiānīs proeliīs cum Germānīs contendunt cum aut suīs fīnibus eōs prohibent aut ipsī in eōrum fīnibus bellum gerunt. eōrum ūna pars quam Gallōs obtinēre dictum est initium capit ā flūmine Rhodanō continētur Garunna flūmine Ōceanō fīnibus Belgārum attingit etiam ab Sēquanīs et Helvētiīs flūmen Rhēnum vergit ad septentriōnēs."
preprocessor = Preprocessor(text=test_text)

# %% [markdown]
# Create structured tokens with data on words, syllables, long by nature, long by position, elision, and accents.

# %%
tokens = preprocessor.tokenize()
print(tokens)
# Out:
# {'title': 'No Title', 'text': [{'contains_abbrev': False, 'plain_text_sentence': 'galliā est omnīs dīvīsa in partēs trēs quārum ūnam incolunt belgae aliam aquītānī tertiam quī ipsōrum lingua celtae nostra gallī appellantur', 'structured_sentence': [{'word': 'galliā', 'index': 0, 'syllables': [{'syllable': 'gal', 'index': 0, 'elide': (False, None), 'long_by_nature': False, 'accented': True, 'long_by_position': (True, None)}, {'syllable': 'li', 'index': 1, 'elide': (False, None), 'long_by_nature': False, 'accented': False, 'long_by_position': (False, None)}, {'syllable': 'ā', 'index': 2, 'elide': (True, 'strong'), 'long_by_nature': True, 'accented': False, 'long_by_position': (False, None)}], 'syllables_count': 3}, {'word': 'est', 'index': 1, 'syllables': [{'syllable': 'est', 'index': 0, 'elide': (False, None), 'long_by_nature': False, 'accented': True, 'long_by_position': (False, None)}], 'syllables_count': 1}, {'word': 'omnīs', 'index': 2, 'syllables': [{'syllable': 'om', 'index': 0, 'elide': (False, None), 'long_by_nature': False, 'accented': True, 'long_by_position': (True, None)}, {'syllable': 'nīs', 'index': 1, 'elide': (False, None), 'long_by_nature': True, 'accented': False, 'long_by_position': (True, None)}], 'syllables_count': 2}, {'word': 'dīvīsa', 'index': 3, 'syllables': [{'syllable': 'dī', 'index': 0, 'elide': (False, None), 'long_by_nature': True, 'accented': False, 'long_by_position': (False, None)}, {'syllable': 'vī', 'index': 1, 'elide': (False, None), 'long_by_nature': True, 'accented': True, 'long_by_position': (False, None)}, {'syllable': 'sa', 'index': 2, 'elide': (True, 'weak'), 'long_by_nature': False, 'accented': False, 'long_by_position': (False, None)}], 'syllables_count': 3}, {'word': 'in', 'index': 4, 'syllables': [{'syllable': 'in', 'index': 0, 'elide': (False, None), 'long_by_nature': False, 'accented': True, 'long_by_position': (True, None)}], 'syllables_count': 1}, {'word': 'partēs', 'index': 5, 'syllables': [{'syllable': 'par', 'index': 0, 'elide': (False, None), 'long_by_nature': False, 'accented': True, 'long_by_position': (True, None)}, {'syllable': 'tēs', 'index': 1, 'elide': (False, None), 'long_by_nature': True, 'accented': False, 'long_by_position': (True, None)}], 'syllables_count': 2}, {'word': 'trēs', 'index': 6, 'syllables': [{'syllable': 'trēs', 'index': 0, 'elide': (False, None), 'long_by_nature': True, 'accented': True, 'long_by_position': (True, None)}], 'syllables_count': 1}, {'word': 'quārum', 'index': 7, 'syllables': [{'syllable': 'quā', 'index': 0, 'elide': (False, None), 'long_by_nature': True, 'accented': True, 'long_by_position': (False, None)}, {'syllable': 'rum', 'index': 1, 'elide': (True, 'strong'), 'long_by_nature': False, 'accented': False, 'long_by_position': (False, None)}], 'syllables_count': 2}, {'word': 'ūnam', 'index': 8, 'syllables': [{'syllable': 'ū', 'index': 0, 'elide': (False, None), 'long_by_nature': True, 'accented': True, 'long_by_position': (False, None)}, {'syllable': 'nam', 'index': 1, 'elide': (True, 'strong'), 'long_by_nature': False, 'accented': False, 'long_by_position': (False, None)}], 'syllables_count': 2}, {'word': 'incolunt', 'index': 9, 'syllables': [{'syllable': 'in', 'index': 0, 'elide': (False, None), 'long_by_nature': False, 'accented': True, 'long_by_position': (True, None)}, {'syllable': 'co', 'index': 1, 'elide': (False, None), 'long_by_nature': False, 'accented': False, 'long_by_position': (False, None)}, {'syllable': 'lunt', 'index': 2, 'elide': (False, None), 'long_by_nature': False, 'accented': False, 'long_by_position': (True, None)}], 'syllables_count': 3}, {'word': 'belgae', 'index': 10, 'syllables': [{'syllable': 'bel', 'index': 0, 'elide': (False, None), 'long_by_nature': False, 'accented': True, 'long_by_position': (True, None)}, {'syllable': 'gae', 'index': 1, 'elide': (True, 'weak'), 'long_by_nature': True, 'accented': False, 'long_by_position': (False, None)}], 'syllables_count': 2}, {'word': 'aliam', 'index': 11, 'syllab ...
