# %%
from scipy import stats
import numpy as np
import pandas as pd

# %% [markdown]
# Test of `Scipy` Chi Square Implementation
# ===

# %%
# Quick test of scipy chi square implementation
e = np.array([1755, 952, 790, 178, 705])
o = np.array([490, 279, 250, 50, 193])
stats.chi2_contingency(np.stack([e, o]))
# Out:
# (2.5348285580374093,
#  0.6384102476401078,
#  4,
#  array([[1742.83941865,  955.65047855,  807.37327189,  177.00106345,
#           697.13576746],
#         [ 502.16058135,  275.34952145,  232.62672811,   50.99893655,
#           200.86423254]]))

# %% [markdown]
# Totals of 5 Rhythm Categories for Cicero's Speeches
# ===

# %%
cicero_speeches = pd.read_csv('../data/cicero_speeches_pca.csv')
cicero_speeches = cicero_speeches.drop(columns=['Unnamed: 0'])
cicero_speeches_total = pd.DataFrame()
cicero_speeches_total['cretic-trochee'] = cicero_speeches[['cretic-trochee (-u--x)', 'cretic-trochee 1 res (uuu--x)',
       'cretic-trochee 1 res (-uuu-x)', 'cretic-trochee 1 res (-u-uux)']].sum(axis=1)
cicero_speeches_total['double-molossus-cretic'] = cicero_speeches[['double/molossus-cretic pure double-cretic (-u--ux)',
       'double/molossus-cretic pure molossus-cretic (----ux)',
       'double/molossus-cretic 1 res (uuu--ux)',
       'double/molossus-cretic 1 res (-uuu-ux)',
       'double/molossus-cretic 1 res (-u-uuux)',
       'double/molossus-cretic molossus not chor 1 res (uu---ux)',
       'double/molossus-cretic molossus not chor 1 res (--uu-ux)',
       'double/molossus-cretic molossus not chor 1 res (---uuux)',
       'double/molossus-cretic chor res (-uu--ux)',
       'double/molossus-cretic ep res (-u---ux)']].sum(axis=1)
cicero_speeches_total['double-trochee'] = cicero_speeches[['double trochee (-u-x)',
       'double trochee 1 res (uuu-x)', 'double trochee 1 res (-uuux)']].sum(axis=1)
cicero_speeches_total['hypodochmiac'] = cicero_speeches[['hypodochmiac (-u-ux)', 'hypodochmiac 1 res (uuu-ux)',
       'hypodochmiac 1 res (-uuuux)']].sum(axis=1)
cicero_speeches_total['other'] = cicero_speeches[['spondaic (---x)', 'heroic (-uu-x)',
       'first paeon (-uux)', 'choriamb trochee (-uu--x)',
       'short sequence (uuuuux)', 'misc_clausulae']].sum(axis=1)
cicero_speeches_total['title'] = cicero_speeches['title'].values

# %%
cicero_speeches_total.head()
# Out:
#    cretic-trochee  double-molossus-cretic  double-trochee  hypodochmiac  \
# 0             215                     146             236            45
# 1             136                      78             116            13
# 2              35                      33              44            11
# 3             175                     117             137            39
# 4              21                      24              17             5
#
#    other                   title
# 0    102             de domo sua
# 1     59  de haruspicum responso
# 2     19       de lege agraria 1
# 3     96       de lege agraria 2
# 4     16       de lege agraria 3

# %% [markdown]
# Method for Generating Chi Square Results
# ===

# %%
def chi_square_corpus(df):
    titles = df['title'].values
    chis = []
    ps = []
    for t in titles:
        speech = df.loc[df['title'] == t]
        speech = speech.drop(columns=['title'])
        rest_of_speeches = df.loc[df['title'] != t]
        rest_of_speeches = rest_of_speeches.drop(columns=['title'])
        rest_of_speeches = rest_of_speeches.sum(axis=0)
        rest_of_speeches = pd.DataFrame(data=rest_of_speeches).T
        test_df = speech.append(rest_of_speeches)
        chi, p, dof, table = stats.chi2_contingency(test_df)
        chis.append(chi)
        ps.append(p)
    new_df = pd.DataFrame()
    new_df['title'] = titles
    new_df['chi'] = chis
    new_df['p'] = [round(p, 5) for p in ps]
    return new_df

# %% [markdown]
# Chi Square Table of 5 Rhythm Categories for Cicero's Speeches
# ===

# %%
cicero_totaled_chi_df = chi_square_corpus(cicero_speeches_total)

# %%
cicero_totaled_chi_df
# Out:
#                             title         chi        p
# 0                     de domo sua   23.330701  0.00011
# 1          de haruspicum responso   14.462578  0.00596
# 2               de lege agraria 1    5.255350  0.26209
# 3               de lege agraria 2    8.543234  0.07359
# 4               de lege agraria 3    2.355887  0.67061
# 5      de provinciis consularibus   19.136572  0.00074
# 6                    in caecilium    4.302021  0.36667
# 7                  in catilinam 1   12.122659  0.01646
# 8                  in catilinam 2   10.688040  0.03030
# 9                  in catilinam 3   11.604888  0.02054
# 10                 in catilinam 4   13.476694  0.00917
# 11                     in pisonem    7.579625  0.10825
# 12                    in vatinium    6.345837  0.17477
# 13                    in verrem 1   11.378087  0.02263
# 14                  in verrem 2 1   25.968961  0.00003
# 15                  in verrem 2 2   19.514286  0.00062
# 16                  in verrem 2 3   16.607740  0.00230
# 17                  in verrem 2 4    7.614409  0.10677
# 18                  in verrem 2 5    6.423261  0.16969
# 19                  philippicae 1    2.700351  0.60915
# 20                 philippicae 10    8.990242  0.06134
# 21                 philippicae 11   12.541015  0.01375
# 22                 philippicae 12   30.160599  0.00000
# 23                 philippicae 13    5.216999  0.26575
# 24                 philippicae 14   10.162344  0.03778
# 25                  philippicae 2    4.831529  0.30502
# 26                  philippicae 3    9.775299  0.04439
# 27                  philippicae 4   11.351992  0.02288
# 28                  philippicae 5    9.723550  0.04535
# 29                  philippicae 6    1.592517  0.81014
# 30                  philippicae 7    8.246524  0.08295
# 31                  philippicae 8   13.290328  0.00994
# 32                  philippicae 9    6.121143  0.19028
# 33        post reditum ad populum   14.815715  0.00510
# 34         post reditum in senatu   23.015709  0.00013
# 35                     pro archia   13.766879  0.00808
# 36                      pro balbo   55.592459  0.00000
# 37                    pro caecina   11.824901  0.01870
# 38                     pro caelio   19.028013  0.00078
# 39                   pro cluentio    6.163063  0.18730
# 40                     pro flacco    9.059646  0.05963
# 41                    pro fonteio    5.832488  0.21201
# 42               pro lege manilia   64.474697  0.00000
# 43                    pro ligario    4.405655  0.35388
# 44                   pro marcello   24.053346  0.00008
# 45                     pro milone    9.288759  0.05427
# 46                     pro murena    4.617411  0.32885
# 47                    pro plancio   41.314313  0.00000
# 48                   pro quinctio   32.831154  0.00000
# 49  pro rabirio perduellionis reo    0.647588  0.95763
# 50            pro rabirio postumo   16.710154  0.00220
# 51              pro rege deiotaro   14.085808  0.00703
# 52             pro roscio amerino   38.255333  0.00000
# 53             pro roscio comoedo  142.209746  0.00000
# 54                     pro scauro   14.460469  0.00596
# 55                     pro sestio   34.145162  0.00000
# 56                      pro sulla    4.676364  0.32214
# 57                     pro tullio   24.356647  0.00007

# %% [markdown]
# Chi Square of Cicero Speeches for all Categories
# ===

# %%
cicero_speeches.head()
# Out:
#                     title  cretic-trochee (-u--x)  \
# 0             de domo sua                     137
# 1  de haruspicum responso                      82
# 2       de lege agraria 1                      23
# 3       de lege agraria 2                     131
# 4       de lege agraria 3                      13
#
#    cretic-trochee 1 res (uuu--x)  cretic-trochee 1 res (-uuu-x)  \
# 0                             16                             51
# 1                              8                             37
# 2                              2                              6
# 3                              8                             26
# 4                              2                              3
#
#    cretic-trochee 1 res (-u-uux)  \
# 0                             11
# 1                              9
# 2                              4
# 3                             10
# 4                              3
#
#    double/molossus-cretic pure double-cretic (-u--ux)  \
# 0                                                 61
# 1                                                 26
# 2                                                 12
# 3                                                 35
# 4                                                 11
#
#    double/molossus-cretic pure molossus-cretic (----ux)  \
# 0                                                 35
# 1                                                 26
# 2                                                 13
# 3                                                 38
# 4                                                  9
#
#    double/molossus-cretic 1 res (uuu--ux)  \
# 0                                      11
# 1                                       4
# 2                                       2
# 3                                       4
# 4                                       1
#
#    double/molossus-cretic 1 res (-uuu-ux)  \
# 0                                       4
# 1                                       2
# 2                                       0
# 3                                       3
# 4                                       0
#
#    double/molossus-cretic 1 res (-u-uuux)   ...    hypodochmiac (-u-ux)  \
# 0                                       1   ...                      42
# 1                                       1   ...                      12
# 2                                       0   ...                      10
# 3                                       2   ...                      38
# 4                                       0   ...                       4
#
#    hypodochmiac 1 res (uuu-ux)  hypodochmiac 1 res (-uuuux)  spondaic (---x)  \
# 0                            2                            1               52
# 1                            0                            1               41
# 2                            1                            0               13
# 3                            1                            0               49
# 4                            1                            0                9
#
#    heroic (-uu-x)  first paeon (-uux)  choriamb trochee (-uu--x)  \
# 0              13                  14                          5
# 1              11                   2                          2
# 2               0                   1                          0
# 3              15                  16                          5
# 4               1                   1                          0
#
#    short sequence (uuuuux)  misc_clausulae  author
# 0                        1              17  cicero
# 1                        1               2  cicero
# 2                        0               5  cicero
# 3                        0              11  cicero
# 4                        0               5  cicero
#
# [5 rows x 28 columns]

# %%
chi_square_corpus(cicero_speeches.drop(columns=['author']))
# Out:
#                             title         chi        p
# 0                     de domo sua   40.957185  0.02320
# 1          de haruspicum responso   42.039523  0.01780
# 2               de lege agraria 1   27.379938  0.33718
# 3               de lege agraria 2   30.631379  0.20152
# 4               de lege agraria 3   28.830866  0.27105
# 5      de provinciis consularibus   48.669721  0.00310
# 6                    in caecilium   18.159192  0.83556
# 7                  in catilinam 1   41.213250  0.02180
# 8                  in catilinam 2   30.848473  0.19409
# 9                  in catilinam 3   27.586805  0.32722
# 10                 in catilinam 4   32.777516  0.13672
# 11                     in pisonem   29.459231  0.24518
# 12                    in vatinium   25.600041  0.42918
# 13                    in verrem 1   37.215435  0.05507
# 14                  in verrem 2 1   67.031108  0.00001
# 15                  in verrem 2 2   64.543472  0.00002
# 16                  in verrem 2 3   47.808148  0.00393
# 17                  in verrem 2 4   38.814598  0.03845
# 18                  in verrem 2 5   34.121472  0.10534
# 19                  philippicae 1   24.947404  0.46532
# 20                 philippicae 10   27.841977  0.31518
# 21                 philippicae 11   52.330907  0.00109
# 22                 philippicae 12   58.712238  0.00016
# 23                 philippicae 13   53.298377  0.00082
# 24                 philippicae 14   38.473987  0.04156
# 25                  philippicae 2   61.992605  0.00006
# 26                  philippicae 3   54.691596  0.00054
# 27                  philippicae 4   34.869720  0.09059
# 28                  philippicae 5   32.119082  0.15460
# 29                  philippicae 6   25.910301  0.41240
# 30                  philippicae 7   23.238753  0.56362
# 31                  philippicae 8   36.033100  0.07110
# 32                  philippicae 9   25.325116  0.44428
# 33        post reditum ad populum   34.913051  0.08979
# 34         post reditum in senatu   36.716716  0.06141
# 35                     pro archia   24.795612  0.47387
# 36                      pro balbo   71.717714  0.00000
# 37                    pro caecina   35.880645  0.07343
# 38                     pro caelio   41.398037  0.02084
# 39                   pro cluentio   53.656472  0.00074
# 40                     pro flacco   23.423676  0.55284
# 41                    pro fonteio   21.115545  0.68615
# 42               pro lege manilia   87.046297  0.00000
# 43                    pro ligario   29.934051  0.22677
# 44                   pro marcello   73.056438  0.00000
# 45                     pro milone   29.822743  0.23099
# 46                     pro murena   29.964556  0.22562
# 47                    pro plancio   58.299957  0.00018
# 48                   pro quinctio   85.643725  0.00000
# 49  pro rabirio perduellionis reo   24.718303  0.47825
# 50            pro rabirio postumo   37.893521  0.04738
# 51              pro rege deiotaro   51.459692  0.00140
# 52             pro roscio amerino  107.585547  0.00000
# 53             pro roscio comoedo  196.054557  0.00000
# 54                     pro scauro   34.660358  0.09453
# 55                     pro sestio   63.017519  0.00004
# 56                      pro sulla   22.206426  0.62380
# 57                     pro tullio   65.115250  0.00002

# %% [markdown]
# Rhythmic/Unrhythmic Table of Cicero's Speeches
# ===

# %%
rhythmic_unrhythmic_cicero_speeches_df = pd.DataFrame()
rhythmic_unrhythmic_cicero_speeches_df['rhythmic'] = cicero_speeches_total[[
    'cretic-trochee', 'double-molossus-cretic', 'double-trochee', 'hypodochmiac'
]].sum(axis=1)
rhythmic_unrhythmic_cicero_speeches_df['unrhythmic'] = cicero_speeches_total['other'].values
rhythmic_unrhythmic_cicero_speeches_df['title'] = cicero_speeches_total['title'].values
rhythmic_unrhythmic_cicero_speeches_df.head()
# Out:
#    rhythmic  unrhythmic                   title
# 0       642         102             de domo sua
# 1       343          59  de haruspicum responso
# 2       123          19       de lege agraria 1
# 3       468          96       de lege agraria 2
# 4        67          16       de lege agraria 3

# %%
rhythmic_unrhythmic_cicero_speeches_chi = chi_square_corpus(rhythmic_unrhythmic_cicero_speeches_df)
rhythmic_unrhythmic_cicero_speeches_chi
# Out:
#                             title         chi        p
# 0                     de domo sua    6.916403  0.00854
# 1          de haruspicum responso    1.886225  0.16963
# 2               de lege agraria 1    1.320256  0.25055
# 3               de lege agraria 2    0.028352  0.86628
# 4               de lege agraria 3    0.097904  0.75436
# 5      de provinciis consularibus    7.665223  0.00563
# 6                    in caecilium    1.278808  0.25812
# 7                  in catilinam 1    1.122944  0.28929
# 8                  in catilinam 2    4.526056  0.03338
# 9                  in catilinam 3    1.137329  0.28622
# 10                 in catilinam 4   10.639004  0.00111
# 11                     in pisonem    0.945903  0.33076
# 12                    in vatinium    4.083166  0.04331
# 13                    in verrem 1    0.310919  0.57712
# 14                  in verrem 2 1   14.321320  0.00015
# 15                  in verrem 2 2    6.689260  0.00970
# 16                  in verrem 2 3    3.654804  0.05591
# 17                  in verrem 2 4    0.776599  0.37818
# 18                  in verrem 2 5    0.002231  0.96232
# 19                  philippicae 1    0.000305  0.98606
# 20                 philippicae 10    0.201479  0.65353
# 21                 philippicae 11    1.668518  0.19646
# 22                 philippicae 12    0.959195  0.32739
# 23                 philippicae 13    0.602563  0.43760
# 24                 philippicae 14    3.237492  0.07197
# 25                  philippicae 2    1.929183  0.16485
# 26                  philippicae 3    4.603974  0.03190
# 27                  philippicae 4    7.548945  0.00600
# 28                  philippicae 5    0.518762  0.47137
# 29                  philippicae 6    0.347668  0.55544
# 30                  philippicae 7    0.726495  0.39402
# 31                  philippicae 8    5.247876  0.02197
# 32                  philippicae 9    4.456033  0.03478
# 33        post reditum ad populum    1.870552  0.17141
# 34         post reditum in senatu    0.784392  0.37580
# 35                     pro archia    4.723012  0.02976
# 36                      pro balbo   17.735700  0.00003
# 37                    pro caecina   10.182275  0.00142
# 38                     pro caelio    7.843469  0.00510
# 39                   pro cluentio    0.061206  0.80460
# 40                     pro flacco    0.431545  0.51123
# 41                    pro fonteio    0.209036  0.64752
# 42               pro lege manilia   10.780683  0.00103
# 43                    pro ligario    1.033892  0.30925
# 44                   pro marcello    9.061424  0.00261
# 45                     pro milone    0.489622  0.48410
# 46                     pro murena    2.348565  0.12540
# 47                    pro plancio    8.571620  0.00341
# 48                   pro quinctio   20.932040  0.00000
# 49  pro rabirio perduellionis reo    0.090803  0.76316
# 50            pro rabirio postumo    3.400367  0.06518
# 51              pro rege deiotaro    1.172990  0.27879
# 52             pro roscio amerino   17.015331  0.00004
# 53             pro roscio comoedo  140.543401  0.00000
# 54                     pro scauro    0.916781  0.33832
# 55                     pro sestio    1.535794  0.21524
# 56                      pro sulla    0.251701  0.61588
# 57                     pro tullio   15.231902  0.00010

# %% [markdown]
# Total of 5 Rhythm Categories of Tacitus
# ===

# %%
tacitus = pd.read_csv('../data/tacitus_pca.csv')
tacitus = tacitus.drop(columns=['Unnamed: 0'])
tacitus_total = pd.DataFrame()
tacitus_total['cretic-trochee'] = tacitus[['cretic-trochee (-u--x)', 'cretic-trochee 1 res (uuu--x)',
       'cretic-trochee 1 res (-uuu-x)', 'cretic-trochee 1 res (-u-uux)']].sum(axis=1)
tacitus_total['double-molossus-cretic'] = tacitus[['double/molossus-cretic pure double-cretic (-u--ux)',
       'double/molossus-cretic pure molossus-cretic (----ux)',
       'double/molossus-cretic 1 res (uuu--ux)',
       'double/molossus-cretic 1 res (-uuu-ux)',
       'double/molossus-cretic 1 res (-u-uuux)',
       'double/molossus-cretic molossus not chor 1 res (uu---ux)',
       'double/molossus-cretic molossus not chor 1 res (--uu-ux)',
       'double/molossus-cretic molossus not chor 1 res (---uuux)',
       'double/molossus-cretic chor res (-uu--ux)',
       'double/molossus-cretic ep res (-u---ux)']].sum(axis=1)
tacitus_total['double-trochee'] = tacitus[['double trochee (-u-x)',
       'double trochee 1 res (uuu-x)', 'double trochee 1 res (-uuux)']].sum(axis=1)
tacitus_total['hypodochmiac'] = tacitus[['hypodochmiac (-u-ux)', 'hypodochmiac 1 res (uuu-ux)',
       'hypodochmiac 1 res (-uuuux)']].sum(axis=1)
tacitus_total['other'] = tacitus[['spondaic (---x)', 'heroic (-uu-x)',
       'first paeon (-uux)', 'choriamb trochee (-uu--x)',
       'short sequence (uuuuux)', 'misc_clausulae']].sum(axis=1)
tacitus_total['title'] = tacitus['title'].values

# %%
tacitus_total.head()
# Out:
#    cretic-trochee  double-molossus-cretic  double-trochee  hypodochmiac  \
# 0            69.0                    74.0            83.0          33.0
# 1           106.0                   141.0           131.0          44.0
# 2            49.0                    54.0            58.0          27.0
# 3            90.0                    69.0            79.0          32.0
# 4            65.0                    70.0            82.0          28.0
#
#    other            title
# 0  175.0         agricola
# 1  332.0   annales book 1
# 2  123.0  annales book 11
# 3  199.0  annales book 12
# 4  194.0  annales book 13

# %% [markdown]
# Chi Square Table of 5 Rhythm Categories for Tacitus
# ===

# %%
tacitus_total_chi = chi_square_corpus(tacitus_total)
tacitus_total_chi
# Out:
#                title        chi        p
# 0           agricola   3.448332  0.48578
# 1     annales book 1   5.931865  0.20429
# 2    annales book 11   5.006846  0.28660
# 3    annales book 12   3.609361  0.46145
# 4    annales book 13   2.479791  0.64826
# 5    annales book 14   5.275282  0.26020
# 6    annales book 15   0.593708  0.96376
# 7    annales book 16   2.822316  0.58799
# 8     annales book 2  21.870342  0.00021
# 9     annales book 3   3.732413  0.44343
# 10    annales book 4   7.962609  0.09296
# 11    annales book 5   2.154270  0.70741
# 12    annales book 6   0.834581  0.93375
# 13          dialogus  27.822914  0.00001
# 14          germania  19.909178  0.00052
# 15  historiae book 1   3.411247  0.49150
# 16  historiae book 2   5.212429  0.26619
# 17  historiae book 3   0.988715  0.91150
# 18  historiae book 4   5.252659  0.26234
# 19  historiae book 5   1.648499  0.80005

# %% [markdown]
# Chi Square of Tacitus of all Categories
# ===

# %%
tacitus.head()
# Out:
#              title  cretic-trochee (-u--x)  cretic-trochee 1 res (uuu--x)  \
# 0         agricola                    45.0                            2.0
# 1   annales book 1                    66.0                           10.0
# 2  annales book 11                    25.0                            5.0
# 3  annales book 12                    45.0                            8.0
# 4  annales book 13                    43.0                           11.0
#
#    cretic-trochee 1 res (-uuu-x)  cretic-trochee 1 res (-u-uux)  \
# 0                            9.0                           13.0
# 1                            8.0                           22.0
# 2                            6.0                           13.0
# 3                           16.0                           21.0
# 4                            6.0                            5.0
#
#    double/molossus-cretic pure double-cretic (-u--ux)  \
# 0                                               24.0
# 1                                               32.0
# 2                                               18.0
# 3                                               19.0
# 4                                               16.0
#
#    double/molossus-cretic pure molossus-cretic (----ux)  \
# 0                                               15.0
# 1                                               34.0
# 2                                                8.0
# 3                                               15.0
# 4                                               11.0
#
#    double/molossus-cretic 1 res (uuu--ux)  \
# 0                                     2.0
# 1                                     5.0
# 2                                     1.0
# 3                                     4.0
# 4                                     3.0
#
#    double/molossus-cretic 1 res (-uuu-ux)  \
# 0                                     1.0
# 1                                     9.0
# 2                                     2.0
# 3                                     3.0
# 4                                     2.0
#
#    double/molossus-cretic 1 res (-u-uuux)   ...     hypodochmiac (-u-ux)  \
# 0                                     2.0   ...                     29.0
# 1                                     4.0   ...                     35.0
# 2                                     2.0   ...                     20.0
# 3                                     3.0   ...                     27.0
# 4                                     6.0   ...                     21.0
#
#    hypodochmiac 1 res (uuu-ux)  hypodochmiac 1 res (-uuuux)  spondaic (---x)  \
# 0                          3.0                          1.0             95.0
# 1                          2.0                          7.0            184.0
# 2                          1.0                          6.0             74.0
# 3                          2.0                          3.0            111.0
# 4                          1.0                          6.0            115.0
#
#    heroic (-uu-x)  first paeon (-uux)  choriamb trochee (-uu--x)  \
# 0            20.0                37.0                       17.0
# 1            48.0                68.0                       25.0
# 2            18.0                23.0                        7.0
# 3            25.0                42.0                       14.0
# 4            29.0                35.0                       11.0
#
#    short sequence (uuuuux)  misc_clausulae   author
# 0                      2.0             4.0  tacitus
# 1                      0.0             7.0  tacitus
# 2                      0.0             1.0  tacitus
# 3                      1.0             6.0  tacitus
# 4                      2.0             2.0  tacitus
#
# [5 rows x 28 columns]

# %%
chi_square_corpus(tacitus.drop(columns=['author']))
# Out:
#                title        chi        p
# 0           agricola  21.384856  0.67097
# 1     annales book 1  27.335823  0.33932
# 2    annales book 11  20.865542  0.70008
# 3    annales book 12  24.965916  0.46429
# 4    annales book 13  26.085941  0.40302
# 5    annales book 14  19.856461  0.75431
# 6    annales book 15  16.903612  0.88526
# 7    annales book 16  34.536254  0.09693
# 8     annales book 2  39.904518  0.02983
# 9     annales book 3  36.426768  0.06537
# 10    annales book 4  32.148329  0.15377
# 11    annales book 5  20.010297  0.74628
# 12    annales book 6  24.263658  0.50418
# 13          dialogus  61.617029  0.00006
# 14          germania  41.266019  0.02152
# 15  historiae book 1  21.460967  0.66665
# 16  historiae book 2  21.443678  0.66763
# 17  historiae book 3  33.811123  0.11201
# 18  historiae book 4  31.117969  0.18514
# 19  historiae book 5  29.224804  0.25463

# %% [markdown]
# Rhythmic/Unrhythmic Table of Tacitus
# ===

# %%
rhythmic_unrhythmic_tacitus_df = pd.DataFrame()
rhythmic_unrhythmic_tacitus_df['rhythmic'] = tacitus_total[[
    'cretic-trochee', 'double-molossus-cretic', 'double-trochee', 'hypodochmiac'
]].sum(axis=1)
rhythmic_unrhythmic_tacitus_df['unrhythmic'] = tacitus_total['other'].values
rhythmic_unrhythmic_tacitus_df['title'] = tacitus_total['title'].values
rhythmic_unrhythmic_tacitus_df.head()
# Out:
#    rhythmic  unrhythmic            title
# 0     259.0       175.0         agricola
# 1     422.0       332.0   annales book 1
# 2     188.0       123.0  annales book 11
# 3     270.0       199.0  annales book 12
# 4     245.0       194.0  annales book 13

# %%
rhythmic_unrhythmic_tacitus_chi = chi_square_corpus(rhythmic_unrhythmic_tacitus_df)
rhythmic_unrhythmic_tacitus_chi
# Out:
#                title        chi        p
# 0           agricola   0.753002  0.38553
# 1     annales book 1   0.758375  0.38384
# 2    annales book 11   0.987066  0.32046
# 3    annales book 12   0.001383  0.97034
# 4    annales book 13   0.493704  0.48228
# 5    annales book 14   0.153639  0.69508
# 6    annales book 15   0.001404  0.97011
# 7    annales book 16   1.217397  0.26987
# 8     annales book 2   8.616343  0.00333
# 9     annales book 3   0.266083  0.60597
# 10    annales book 4   0.444583  0.50492
# 11    annales book 5   0.032353  0.85725
# 12    annales book 6   0.095536  0.75725
# 13          dialogus  21.635010  0.00000
# 14          germania  15.833226  0.00007
# 15  historiae book 1   2.638150  0.10432
# 16  historiae book 2   1.425361  0.23252
# 17  historiae book 3   0.902657  0.34207
# 18  historiae book 4   1.758208  0.18485
# 19  historiae book 5   0.761906  0.38273

# %% [markdown]
# Total of 5 Rhythm Categories of Pliny
# ===

# %%
pliny = pd.read_csv('../data/pliny_pca.csv')
pliny = pliny.loc[pliny['title'] != 'versus']
pliny = pliny.drop(columns=['Unnamed: 0'])
pliny_total = pd.DataFrame()
pliny_total['cretic-trochee'] = pliny[['cretic-trochee (-u--x)', 'cretic-trochee 1 res (uuu--x)',
       'cretic-trochee 1 res (-uuu-x)', 'cretic-trochee 1 res (-u-uux)']].sum(axis=1)
pliny_total['double-molossus-cretic'] = pliny[['double/molossus-cretic pure double-cretic (-u--ux)',
       'double/molossus-cretic pure molossus-cretic (----ux)',
       'double/molossus-cretic 1 res (uuu--ux)',
       'double/molossus-cretic 1 res (-uuu-ux)',
       'double/molossus-cretic 1 res (-u-uuux)',
       'double/molossus-cretic molossus not chor 1 res (uu---ux)',
       'double/molossus-cretic molossus not chor 1 res (--uu-ux)',
       'double/molossus-cretic molossus not chor 1 res (---uuux)',
       'double/molossus-cretic chor res (-uu--ux)',
       'double/molossus-cretic ep res (-u---ux)']].sum(axis=1)
pliny_total['double-trochee'] = pliny[['double trochee (-u-x)',
       'double trochee 1 res (uuu-x)', 'double trochee 1 res (-uuux)']].sum(axis=1)
pliny_total['hypodochmiac'] = pliny[['hypodochmiac (-u-ux)', 'hypodochmiac 1 res (uuu-ux)',
       'hypodochmiac 1 res (-uuuux)']].sum(axis=1)
pliny_total['other'] = pliny[['spondaic (---x)', 'heroic (-uu-x)',
       'first paeon (-uux)', 'choriamb trochee (-uu--x)',
       'short sequence (uuuuux)', 'misc_clausulae']].sum(axis=1)
pliny_total['title'] = pliny['title'].values

# %%
pliny_total.head()
# Out:
#    cretic-trochee  double-molossus-cretic  double-trochee  hypodochmiac  \
# 0            39.0                    30.0            17.0          15.0
# 1           183.0                    86.0            64.0          21.0
# 2           200.0                    98.0            81.0          20.0
# 3           490.0                   279.0           250.0          50.0
# 5           193.0                   114.0            78.0          21.0
#
#    other                title
# 0   50.0  epistulae 10 trajan
# 1   60.0          epistulae 8
# 2   97.0          epistulae 9
# 3  193.0          panegyricus
# 5   74.0          epistulae 4

# %%
chi_square_corpus(pliny_total)
# Out:
#                   title        chi        p
# 0   epistulae 10 trajan  48.329484  0.00000
# 1           epistulae 8   6.768071  0.14866
# 2           epistulae 9   5.223296  0.26514
# 3           panegyricus   4.041099  0.40047
# 4           epistulae 4   3.266988  0.51418
# 5           epistulae 5   7.082810  0.13158
# 6           epistulae 7   4.606982  0.33005
# 7    epistulae 10 pliny  15.531704  0.00372
# 8           epistulae 6   0.402412  0.98228
# 9           epistulae 2   1.576676  0.81298
# 10          epistulae 3  12.146040  0.01630
# 11          epistulae 1   1.626018  0.80411

# %% [markdown]
# Chi of Rhythms of All Categories Pliny
# ===

# %%
pliny.head()
# Out:
#                  title  cretic-trochee (-u--x)  cretic-trochee 1 res (uuu--x)  \
# 0  epistulae 10 trajan                    22.0                            6.0
# 1          epistulae 8                   114.0                           11.0
# 2          epistulae 9                   117.0                           18.0
# 3          panegyricus                   298.0                           30.0
# 5          epistulae 4                   113.0                           13.0
#
#    cretic-trochee 1 res (-uuu-x)  cretic-trochee 1 res (-u-uux)  \
# 0                            4.0                            7.0
# 1                           19.0                           39.0
# 2                           19.0                           46.0
# 3                           60.0                          102.0
# 5                           21.0                           46.0
#
#    double/molossus-cretic pure double-cretic (-u--ux)  \
# 0                                               10.0
# 1                                               46.0
# 2                                               53.0
# 3                                              162.0
# 5                                               75.0
#
#    double/molossus-cretic pure molossus-cretic (----ux)  \
# 0                                                7.0
# 1                                                9.0
# 2                                               12.0
# 3                                               29.0
# 5                                               12.0
#
#    double/molossus-cretic 1 res (uuu--ux)  \
# 0                                     0.0
# 1                                     6.0
# 2                                    18.0
# 3                                    22.0
# 5                                     9.0
#
#    double/molossus-cretic 1 res (-uuu-ux)  \
# 0                                     2.0
# 1                                     8.0
# 2                                     2.0
# 3                                    11.0
# 5                                     2.0
#
#    double/molossus-cretic 1 res (-u-uuux)   ...    hypodochmiac (-u-ux)  \
# 0                                     1.0   ...                    15.0
# 1                                     0.0   ...                    20.0
# 2                                     2.0   ...                    16.0
# 3                                     8.0   ...                    45.0
# 5                                     1.0   ...                    20.0
#
#    hypodochmiac 1 res (uuu-ux)  hypodochmiac 1 res (-uuuux)  spondaic (---x)  \
# 0                          0.0                          0.0             26.0
# 1                          1.0                          0.0             21.0
# 2                          4.0                          0.0             32.0
# 3                          2.0                          3.0            101.0
# 5                          0.0                          1.0             30.0
#
#    heroic (-uu-x)  first paeon (-uux)  choriamb trochee (-uu--x)  \
# 0             6.0                14.0                        3.0
# 1            13.0                11.0                        9.0
# 2            15.0                16.0                        7.0
# 3            21.0                28.0                       24.0
# 5             8.0                14.0                        8.0
#
#    short sequence (uuuuux)  misc_clausulae  author
# 0                      0.0             1.0   pliny
# 1                      2.0             4.0   pliny
# 2                     14.0            13.0   pliny
# 3                      1.0            18.0   pliny
# 5                      3.0            11.0   pliny
#
# [5 rows x 28 columns]

# %%
chi_square_corpus(pliny.drop(columns=['author']))
# Out:
#                   title         chi        p
# 0   epistulae 10 trajan  107.208419  0.00000
# 1           epistulae 8   32.495930  0.14416
# 2           epistulae 9   87.359426  0.00000
# 3           panegyricus   29.681086  0.23645
# 4           epistulae 4   17.630841  0.85765
# 5           epistulae 5   24.266104  0.50404
# 6           epistulae 7   20.947681  0.69552
# 7    epistulae 10 pliny   31.676379  0.16759
# 8           epistulae 6   23.587813  0.54328
# 9           epistulae 2   20.952075  0.69528
# 10          epistulae 3   34.296031  0.10173
# 11          epistulae 1   38.389746  0.04236

# %% [markdown]
# Rhythmic/Unrhythmic Pliny
# ===

# %%
rhythmic_unrhythmic_pliny_df = pd.DataFrame()
rhythmic_unrhythmic_pliny_df['rhythmic'] = pliny_total[[
    'cretic-trochee', 'double-molossus-cretic', 'double-trochee', 'hypodochmiac'
]].sum(axis=1)
rhythmic_unrhythmic_pliny_df['unrhythmic'] = pliny_total['other'].values
rhythmic_unrhythmic_pliny_df['title'] = pliny_total['title'].values
rhythmic_unrhythmic_pliny_df.head()
# Out:
#    rhythmic  unrhythmic                title
# 0     101.0        50.0  epistulae 10 trajan
# 1     354.0        60.0          epistulae 8
# 2     399.0        97.0          epistulae 9
# 3    1069.0       193.0          panegyricus
# 5     406.0        74.0          epistulae 4

# %%
chi_square_corpus(rhythmic_unrhythmic_pliny_df)
# Out:
#                   title        chi        p
# 0   epistulae 10 trajan  29.451760  0.00000
# 1           epistulae 8   1.221749  0.26902
# 2           epistulae 9   3.261127  0.07094
# 3           panegyricus   1.739514  0.18720
# 4           epistulae 4   0.410015  0.52196
# 5           epistulae 5   1.974811  0.15994
# 6           epistulae 7   0.007131  0.93270
# 7    epistulae 10 pliny   2.367095  0.12392
# 8           epistulae 6   0.011651  0.91405
# 9           epistulae 2   0.590060  0.44240
# 10          epistulae 3   0.020642  0.88576
# 11          epistulae 1   0.234935  0.62789

# %% [markdown]
# Epistulae Books 1-9 Tests
# ===

# %%
rows_to_exclude = ['epistulae 10 trajan', 'panegyricus', 'epistulae 10 pliny']
pliny_total_epist = pliny_total.loc[~pliny_total['title'].isin(rows_to_exclude)]
pliny_total_epist
# Out:
#     cretic-trochee  double-molossus-cretic  double-trochee  hypodochmiac  \
# 1            183.0                    86.0            64.0          21.0
# 2            200.0                    98.0            81.0          20.0
# 5            193.0                   114.0            78.0          21.0
# 6            184.0                   120.0            79.0          18.0
# 7            207.0                   104.0            80.0          15.0
# 9            215.0                   123.0           101.0          26.0
# 10           192.0                   100.0            96.0          19.0
# 11           196.0                    92.0           119.0          16.0
# 12           185.0                   115.0            92.0          22.0
#
#     other        title
# 1    60.0  epistulae 8
# 2    97.0  epistulae 9
# 5    74.0  epistulae 4
# 6    66.0  epistulae 5
# 7    82.0  epistulae 7
# 9    94.0  epistulae 6
# 10   73.0  epistulae 2
# 11   82.0  epistulae 3
# 12   77.0  epistulae 1

# %%
chi_square_corpus(pliny_total_epist)
# Out:
#          title        chi        p
# 0  epistulae 8   5.703863  0.22238
# 1  epistulae 9   6.080320  0.19323
# 2  epistulae 4   2.246296  0.69056
# 3  epistulae 5   5.502795  0.23948
# 4  epistulae 7   3.119654  0.53801
# 5  epistulae 6   1.184584  0.88063
# 6  epistulae 2   1.633216  0.80281
# 7  epistulae 3  14.278306  0.00646
# 8  epistulae 1   1.957737  0.74353

# %%
rhythmic_unrhythmic_pliny_epist_df = rhythmic_unrhythmic_pliny_df[~rhythmic_unrhythmic_pliny_df['title'].isin(rows_to_exclude)]
rhythmic_unrhythmic_pliny_epist_df
# Out:
#     rhythmic  unrhythmic        title
# 1      354.0        60.0  epistulae 8
# 2      399.0        97.0  epistulae 9
# 5      406.0        74.0  epistulae 4
# 6      401.0        66.0  epistulae 5
# 7      406.0        82.0  epistulae 7
# 9      465.0        94.0  epistulae 6
# 10     407.0        73.0  epistulae 2
# 11     423.0        82.0  epistulae 3
# 12     414.0        77.0  epistulae 1

# %%
chi_square_corpus(rhythmic_unrhythmic_pliny_epist_df)
# Out:
#          title       chi        p
# 0  epistulae 8  0.743932  0.38840
# 1  epistulae 9  4.675128  0.03060
# 2  epistulae 4  0.132000  0.71637
# 3  epistulae 5  1.333422  0.24820
# 4  epistulae 7  0.148810  0.69968
# 5  epistulae 6  0.188561  0.66412
# 6  epistulae 2  0.244968  0.62064
# 7  epistulae 3  0.000771  0.97784
# 8  epistulae 1  0.039802  0.84187

# %% [markdown]
# Varro Tests
# ===

# %%
varro = pd.read_csv('../data/varro_df.csv')
varro = varro.drop(columns=['total_clausulae', 'total_excluded', 'abbrev_excluded', 'bracket_excluded', 'short_excluded', 'total_artistic', 'percent_clausulae'])
rows_to_include = ['de lingua latina book 5' , 'de lingua latina book 6', 'de lingua latina book 7', 'de lingua latina book 8', 'de lingua latina book 9', 'res rustica book 1', 'res rustica book 2', 'res rustica book 3']
varro = varro.loc[varro['title'].isin(rows_to_include)]
varro_total = pd.DataFrame()
varro_total['cretic-trochee'] = varro[['cretic-trochee (-u--x)', 'cretic-trochee 1 res (uuu--x)',
       'cretic-trochee 1 res (-uuu-x)', 'cretic-trochee 1 res (-u-uux)']].sum(axis=1)
varro_total['double-molossus-cretic'] = varro[['double/molossus-cretic pure double-cretic (-u--ux)',
       'double/molossus-cretic pure molossus-cretic (----ux)',
       'double/molossus-cretic 1 res (uuu--ux)',
       'double/molossus-cretic 1 res (-uuu-ux)',
       'double/molossus-cretic 1 res (-u-uuux)',
       'double/molossus-cretic molossus not chor 1 res (uu---ux)',
       'double/molossus-cretic molossus not chor 1 res (--uu-ux)',
       'double/molossus-cretic molossus not chor 1 res (---uuux)',
       'double/molossus-cretic chor res (-uu--ux)',
       'double/molossus-cretic ep res (-u---ux)']].sum(axis=1)
varro_total['double-trochee'] = varro[['double trochee (-u-x)',
       'double trochee 1 res (uuu-x)', 'double trochee 1 res (-uuux)']].sum(axis=1)
varro_total['hypodochmiac'] = varro[['hypodochmiac (-u-ux)', 'hypodochmiac 1 res (uuu-ux)',
       'hypodochmiac 1 res (-uuuux)']].sum(axis=1)
varro_total['other'] = varro[['spondaic (---x)', 'heroic (-uu-x)',
       'first paeon (-uux)', 'choriamb trochee (-uu--x)',
       'short sequence (uuuuux)', 'misc_clausulae']].sum(axis=1)
varro_total['title'] = varro['title'].values

# %%
varro_total
# Out:
#     cretic-trochee  double-molossus-cretic  double-trochee  hypodochmiac  \
# 7            161.0                    98.0           179.0          49.0
# 8             72.0                    52.0            86.0          24.0
# 9             72.0                    85.0            80.0          28.0
# 10            38.0                    33.0            52.0          24.0
# 11           119.0                    72.0           103.0          50.0
# 21           147.0                    60.0           177.0          31.0
# 22           107.0                    68.0           135.0          22.0
# 23           110.0                    35.0           108.0          17.0
#
#     other                    title
# 7   461.0  de lingua latina book 5
# 8   246.0  de lingua latina book 6
# 9   284.0  de lingua latina book 7
# 10  120.0  de lingua latina book 8
# 11  298.0  de lingua latina book 9
# 21  393.0       res rustica book 1
# 22  340.0       res rustica book 2
# 23  278.0       res rustica book 3

# %%
chi_square_corpus(varro_total)
# Out:
#                      title        chi        p
# 0  de lingua latina book 5   0.219121  0.99442
# 1  de lingua latina book 6   1.839035  0.76533
# 2  de lingua latina book 7  28.114991  0.00001
# 3  de lingua latina book 8  12.580828  0.01352
# 4  de lingua latina book 9  17.663949  0.00144
# 5       res rustica book 1  16.432805  0.00249
# 6       res rustica book 2   6.014941  0.19804
# 7       res rustica book 3  17.821260  0.00134

# %%
rhythmic_unrhythmic_varro_df = pd.DataFrame()
rhythmic_unrhythmic_varro_df['rhythmic'] = varro_total[[
    'cretic-trochee', 'double-molossus-cretic', 'double-trochee', 'hypodochmiac'
]].sum(axis=1)
rhythmic_unrhythmic_varro_df['unrhythmic'] = varro_total['other'].values
rhythmic_unrhythmic_varro_df['title'] = varro_total['title'].values
rhythmic_unrhythmic_varro_df.head()
# Out:
#     rhythmic  unrhythmic                    title
# 7      487.0       461.0  de lingua latina book 5
# 8      234.0       246.0  de lingua latina book 6
# 9      265.0       284.0  de lingua latina book 7
# 10     147.0       120.0  de lingua latina book 8
# 11     344.0       298.0  de lingua latina book 9

# %%
chi_square_corpus(rhythmic_unrhythmic_varro_df)
# Out:
#                      title       chi        p
# 0  de lingua latina book 5  0.150346  0.69821
# 1  de lingua latina book 6  0.767344  0.38104
# 2  de lingua latina book 7  1.415178  0.23420
# 3  de lingua latina book 8  1.913706  0.16655
# 4  de lingua latina book 9  2.237209  0.13472
# 5       res rustica book 1  0.115572  0.73389
# 6       res rustica book 2  0.505340  0.47716
# 7       res rustica book 3  0.477906  0.48937

# %% [markdown]
# Caesar Tests
# ===

# %%
caesar = pd.read_csv('../data/caesar_df.csv')
caesar = caesar.drop(columns=['total_clausulae', 'total_excluded', 'abbrev_excluded', 'bracket_excluded', 'short_excluded', 'total_artistic', 'percent_clausulae'])
rows_to_exclude = ['anticato' , 'bellum civile', 'carmina', 'de analogia', 'epistulae ad ciceronem', 'epistulae ad familiares', 'orationes', 'de bello gallico', 'de bello gallico book 8']
caesar = caesar.loc[~caesar['title'].isin(rows_to_exclude)]
caesar_total = pd.DataFrame()
caesar_total['cretic-trochee'] = caesar[['cretic-trochee (-u--x)', 'cretic-trochee 1 res (uuu--x)',
       'cretic-trochee 1 res (-uuu-x)', 'cretic-trochee 1 res (-u-uux)']].sum(axis=1)
caesar_total['double-molossus-cretic'] = caesar[['double/molossus-cretic pure double-cretic (-u--ux)',
       'double/molossus-cretic pure molossus-cretic (----ux)',
       'double/molossus-cretic 1 res (uuu--ux)',
       'double/molossus-cretic 1 res (-uuu-ux)',
       'double/molossus-cretic 1 res (-u-uuux)',
       'double/molossus-cretic molossus not chor 1 res (uu---ux)',
       'double/molossus-cretic molossus not chor 1 res (--uu-ux)',
       'double/molossus-cretic molossus not chor 1 res (---uuux)',
       'double/molossus-cretic chor res (-uu--ux)',
       'double/molossus-cretic ep res (-u---ux)']].sum(axis=1)
caesar_total['double-trochee'] = caesar[['double trochee (-u-x)',
       'double trochee 1 res (uuu-x)', 'double trochee 1 res (-uuux)']].sum(axis=1)
caesar_total['hypodochmiac'] = caesar[['hypodochmiac (-u-ux)', 'hypodochmiac 1 res (uuu-ux)',
       'hypodochmiac 1 res (-uuuux)']].sum(axis=1)
caesar_total['other'] = caesar[['spondaic (---x)', 'heroic (-uu-x)',
       'first paeon (-uux)', 'choriamb trochee (-uu--x)',
       'short sequence (uuuuux)', 'misc_clausulae']].sum(axis=1)
caesar_total['title'] = caesar['title'].values

# %%
caesar
# Out:
#                       title  cretic-trochee (-u--x)  \
# 2      bellum civile book 1                   106.0
# 3      bellum civile book 2                    58.0
# 4      bellum civile book 3                    89.0
# 8   de bello gallico book 1                    52.0
# 9   de bello gallico book 2                    27.0
# 10  de bello gallico book 3                    16.0
# 11  de bello gallico book 4                    32.0
# 12  de bello gallico book 5                    70.0
# 13  de bello gallico book 6                    54.0
# 14  de bello gallico book 7                    79.0
#
#     cretic-trochee 1 res (uuu--x)  cretic-trochee 1 res (-uuu-x)  \
# 2                            15.0                           13.0
# 3                            11.0                           11.0
# 4                            22.0                           21.0
# 8                             6.0                           14.0
# 9                             3.0                            6.0
# 10                            1.0                            7.0
# 11                            2.0                            6.0
# 12                           10.0                            7.0
# 13                            5.0                            8.0
# 14                           12.0                           18.0
#
#     cretic-trochee 1 res (-u-uux)  \
# 2                            19.0
# 3                             5.0
# 4                            14.0
# 8                             8.0
# 9                             3.0
# 10                            1.0
# 11                            5.0
# 12                           17.0
# 13                            9.0
# 14                           20.0
#
#     double/molossus-cretic pure double-cretic (-u--ux)  \
# 2                                                36.0
# 3                                                16.0
# 4                                                29.0
# 8                                                 9.0
# 9                                                 7.0
# 10                                                5.0
# 11                                                6.0
# 12                                               20.0
# 13                                               18.0
# 14                                               24.0
#
#     double/molossus-cretic pure molossus-cretic (----ux)  \
# 2                                                31.0
# 3                                                23.0
# 4                                                39.0
# 8                                                18.0
# 9                                                11.0
# 10                                                3.0
# 11                                               12.0
# 12                                               23.0
# 13                                               18.0
# 14                                               43.0
#
#     double/molossus-cretic 1 res (uuu--ux)  \
# 2                                     11.0
# 3                                      3.0
# 4                                      9.0
# 8                                      1.0
# 9                                      0.0
# 10                                     1.0
# 11                                     1.0
# 12                                     3.0
# 13                                     2.0
# 14                                     3.0
#
#     double/molossus-cretic 1 res (-uuu-ux)  \
# 2                                      1.0
# 3                                      1.0
# 4                                      2.0
# 8                                      1.0
# 9                                      0.0
# 10                                     1.0
# 11                                     0.0
# 12                                     0.0
# 13                                     1.0
# 14                                     1.0
#
#     double/molossus-cretic 1 res (-u-uuux)       ...        \
# 2                                      6.0       ...
# 3                                      5.0       ...
# 4                                      4.0       ...
# 8                                      3.0       ...
# 9                                      2.0       ...
# 10                                     1.0       ...
# 11                                     1.0       ...
# 12                                     0.0       ...
# 13                                     4.0       ...
# 14                                     2.0       ...
#
#     double trochee 1 res (-uuux)  hypodochmiac (-u-ux)  \
# 2                            4.0                  30.0
# 3                            2.0                  12.0
# 4                           12.0                  29.0
# 8                            8.0                   8.0
# 9                            4.0                   9.0
# 10                           0.0                   7.0
# 11                           4.0                   7.0
# 12                           9.0                  22.0
# 13                           5.0                   9.0
# 14                           6.0                  19.0
#
#     hypodochmiac 1 res (uuu-ux)  hypodochmiac 1 res (-uuuux)  spondaic (---x)  \
# 2                           3.0                          3.0            127.0
# 3                           2.0                          3.0             73.0
# 4                           2.0                          3.0            162.0
# 8                           0.0                          5.0            110.0
# 9                           0.0                          2.0             57.0
# 10                          0.0                          1.0             45.0
# 11                          0.0                          0.0             53.0
# 12                          2.0                          2.0             91.0
# 13                          2.0                          1.0             54.0
# 14                          1.0                          1.0            155.0
#
#     heroic (-uu-x)  first paeon (-uux)  choriamb trochee (-uu--x)  \
# 2             22.0                50.0                       22.0
# 3             20.0                29.0                        4.0
# 4             44.0                40.0                       20.0
# 8             28.0                30.0                       16.0
# 9              7.0                 8.0                        4.0
# 10             7.0                 5.0                        3.0
# 11            10.0                12.0                       11.0
# 12            10.0                29.0                        5.0
# 13             8.0                21.0                        6.0
# 14            26.0                47.0                       22.0
#
#     short sequence (uuuuux)  misc_clausulae
# 2                       1.0             4.0
# 3                       3.0             4.0
# 4                       5.0             7.0
# 8                       2.0             2.0
# 9                       1.0             0.0
# 10                      0.0             1.0
# 11                      1.0             3.0
# 12                      3.0             3.0
# 13                      2.0             2.0
# 14                      6.0             9.0
#
# [10 rows x 27 columns]

# %%
chi_square_corpus(caesar_total)
# Out:
#                      title        chi        p
# 0     bellum civile book 1   6.921700  0.14008
# 1     bellum civile book 2   4.123356  0.38957
# 2     bellum civile book 3   1.172055  0.88268
# 3  de bello gallico book 1  26.466583  0.00003
# 4  de bello gallico book 2   3.299387  0.50903
# 5  de bello gallico book 3   8.571934  0.07274
# 6  de bello gallico book 4   3.143200  0.53415
# 7  de bello gallico book 5   9.209554  0.05607
# 8  de bello gallico book 6  12.784196  0.01238
# 9  de bello gallico book 7   5.930376  0.20441

# %%
rhythmic_unrhythmic_caesar_df = pd.DataFrame()
rhythmic_unrhythmic_caesar_df['rhythmic'] = caesar_total[[
    'cretic-trochee', 'double-molossus-cretic', 'double-trochee', 'hypodochmiac'
]].sum(axis=1)
rhythmic_unrhythmic_caesar_df['unrhythmic'] = caesar_total['other'].values
rhythmic_unrhythmic_caesar_df['title'] = caesar_total['title'].values
rhythmic_unrhythmic_caesar_df.head()
# Out:
#    rhythmic  unrhythmic                    title
# 2     461.0       226.0     bellum civile book 1
# 3     241.0       133.0     bellum civile book 2
# 4     463.0       278.0     bellum civile book 3
# 8     272.0       188.0  de bello gallico book 1
# 9     114.0        77.0  de bello gallico book 2

# %%
chi_square_corpus(rhythmic_unrhythmic_caesar_df)
# Out:
#                      title       chi        p
# 0     bellum civile book 1  3.995945  0.04561
# 1     bellum civile book 2  0.071317  0.78943
# 2     bellum civile book 3  0.486002  0.48572
# 3  de bello gallico book 1  4.376196  0.03644
# 4  de bello gallico book 2  1.197931  0.27374
# 5  de bello gallico book 3  0.507890  0.47605
# 6  de bello gallico book 4  2.217653  0.13644
# 7  de bello gallico book 5  2.899216  0.08862
# 8  de bello gallico book 6  8.461044  0.00363
# 9  de bello gallico book 7  1.586164  0.20788
