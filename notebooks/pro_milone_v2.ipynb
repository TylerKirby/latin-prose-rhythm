ignored_text = "Nōn enim corōna cōnsessūs vester cīnctus est ut solēbat nōn ūsitātā frequentiā stīpātī sumus nōn illa praesidia quae prō templīs omnibus cernitis etsī contrā vim conlocāta sunt nōn adferunt tamen ōrātōrī terrōris aliquid ut in forō et in jūdiciō quamquam praesidiīs salūtāribus et necessāriīs saeptī sumus tamen nē nōn timēre quidem sine aliquō timōre possīmus."
preprocessor = Preprocessor(text=ignored_text)
analysis = Analyze()

tokens
# Out:
# {'text': [{'contains_abbrev': False,
#    'contains_numeral': False,
#    'plain_text_sentence': 'etsī vereor, jūdicēs, nē turpe sit prō fortissimō virō dīcere incipientem timēre minimēque deceat, cum 00000 annius ipse magis dē reī pūblicae salūte quam dē suā perturbētur, mē ad ējus causam parem animī magnitūdinem adferre nōn posse, tamen haec novī jūdicī nova fōrma terret oculōs quī, quōcumque incīdērunt, veterem cōnsuētūdinem forī et pristīnum mōrem jūdiciōrum requīrunt',
#    'structured_sentence': [{'index': 0,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'et'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'sī'}],
#      'syllables_count': 2,
#      'word': 'etsī'},
#     {'index': 1,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 've'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'or'}],
#      'syllables_count': 3,
#      'word': 'vereor,'},
#     {'index': 2,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'jū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'cēs'}],
#      'syllables_count': 3,
#      'word': 'jūdicēs,'},
#     {'index': 3,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'nē'}],
#      'syllables_count': 1,
#      'word': 'nē'},
#     {'index': 4,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tur'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'pe'}],
#      'syllables_count': 2,
#      'word': 'turpe'},
#     {'index': 5,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'sit'}],
#      'syllables_count': 1,
#      'word': 'sit'},
#     {'index': 6,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'prō'}],
#      'syllables_count': 1,
#      'word': 'prō'},
#     {'index': 7,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'for'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tis'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'si'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mō'}],
#      'syllables_count': 4,
#      'word': 'fortissimō'},
#     {'index': 8,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'vi'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rō'}],
#      'syllables_count': 2,
#      'word': 'virō'},
#     {'index': 9,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'dī'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ce'},
#       {'accented': False,
#        'elide': (True, 'weak'),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'}],
#      'syllables_count': 3,
#      'word': 'dīcere'},
#     {'index': 10,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'in'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ci'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'pi'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'en'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 4,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tem'}],
#      'syllables_count': 5,
#      'word': 'incipientem'},
#     {'index': 11,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ti'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'}],
#      'syllables_count': 3,
#      'word': 'timēre'},
#     {'index': 12,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'mi'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ni'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'que'}],
#      'syllables_count': 4,
#      'word': 'minimēque'},
#     {'index': 13,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'de'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ce'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'at'}],
#      'syllables_count': 3,
#      'word': 'deceat,'},
#     {'index': 14,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'cum'}],
#      'syllables_count': 1,
#      'word': 'cum'},
#     {'index': 15,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': '00000'}],
#      'syllables_count': 1,
#      'word': '00000'},
#     {'index': 16,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'an'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ni'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'us'}],
#      'syllables_count': 3,
#      'word': 'annius'},
#     {'index': 17,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ip'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'se'}],
#      'syllables_count': 2,
#      'word': 'ipse'},
#     {'index': 18,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ma'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'gis'}],
#      'syllables_count': 2,
#      'word': 'magis'},
#     {'index': 19,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'dē'}],
#      'syllables_count': 1,
#      'word': 'dē'},
#     {'index': 20,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ī'}],
#      'syllables_count': 2,
#      'word': 'reī'},
#     {'index': 21,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, 'mute+liquid'),
#        'syllable': 'pū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'bli'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'cae'}],
#      'syllables_count': 3,
#      'word': 'pūblicae'},
#     {'index': 22,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'sa'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'lū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'te'}],
#      'syllables_count': 3,
#      'word': 'salūte'},
#     {'index': 23,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'quam'}],
#      'syllables_count': 1,
#      'word': 'quam'},
#     {'index': 24,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'dē'}],
#      'syllables_count': 1,
#      'word': 'dē'},
#     {'index': 25,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'su'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ā'}],
#      'syllables_count': 2,
#      'word': 'suā'},
#     {'index': 26,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'per'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tur'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'bē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tur'}],
#      'syllables_count': 4,
#      'word': 'perturbētur,'},
#     {'index': 27,
#      'syllables': [{'accented': True,
#        'elide': (True, 'strong'),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mē'}],
#      'syllables_count': 1,
#      'word': 'mē'},
#     {'index': 28,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ad'}],
#      'syllables_count': 1,
#      'word': 'ad'},
#     {'index': 29,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'jus'}],
#      'syllables_count': 2,
#      'word': 'ējus'},
#     {'index': 30,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'cau'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'sam'}],
#      'syllables_count': 2,
#      'word': 'causam'},
#     {'index': 31,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'pa'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'rem'}],
#      'syllables_count': 2,
#      'word': 'parem'},
#     {'index': 32,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'a'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ni'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mī'}],
#      'syllables_count': 3,
#      'word': 'animī'},
#     {'index': 33,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ma'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'gni'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 4,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'nem'}],
#      'syllables_count': 5,
#      'word': 'magnitūdinem'},
#     {'index': 34,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ad'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'fer'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'}],
#      'syllables_count': 3,
#      'word': 'adferre'},
#     {'index': 35,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'nōn'}],
#      'syllables_count': 1,
#      'word': 'nōn'},
#     {'index': 36,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'pos'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'se'}],
#      'syllables_count': 2,
#      'word': 'posse,'},
#     {'index': 37,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ta'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'men'}],
#      'syllables_count': 2,
#      'word': 'tamen'},
#     {'index': 38,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'haec'}],
#      'syllables_count': 1,
#      'word': 'haec'},
#     {'index': 39,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'no'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'vī'}],
#      'syllables_count': 2,
#      'word': 'novī'},
#     {'index': 40,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'jū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'cī'}],
#      'syllables_count': 3,
#      'word': 'jūdicī'},
#     {'index': 41,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'no'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'va'}],
#      'syllables_count': 2,
#      'word': 'nova'},
#     {'index': 42,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'fōr'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ma'}],
#      'syllables_count': 2,
#      'word': 'fōrma'},
#     {'index': 43,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ter'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ret'}],
#      'syllables_count': 2,
#      'word': 'terret'},
#     {'index': 44,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'o'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'cu'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'lōs'}],
#      'syllables_count': 3,
#      'word': 'oculōs'},
#     {'index': 45,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'quī'}],
#      'syllables_count': 1,
#      'word': 'quī,'},
#     {'index': 46,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'quō'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'cum'},
#       {'accented': False,
#        'elide': (True, 'weak'),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'que'}],
#      'syllables_count': 3,
#      'word': 'quōcumque'},
#     {'index': 47,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'in'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'cī'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'dē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'runt'}],
#      'syllables_count': 4,
#      'word': 'incīdērunt,'},
#     {'index': 48,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 've'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'te'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'rem'}],
#      'syllables_count': 3,
#      'word': 'veterem'},
#     {'index': 49,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'cōn'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'su'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ē'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 4,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 5,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'nem'}],
#      'syllables_count': 6,
#      'word': 'cōnsuētūdinem'},
#     {'index': 50,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'fo'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rī'}],
#      'syllables_count': 2,
#      'word': 'forī'},
#     {'index': 51,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'et'}],
#      'syllables_count': 1,
#      'word': 'et'},
#     {'index': 52,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'pris'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tī'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'num'}],
#      'syllables_count': 3,
#      'word': 'pristīnum'},
#     {'index': 53,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'rem'}],
#      'syllables_count': 2,
#      'word': 'mōrem'},
#     {'index': 54,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'jū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ci'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 4,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'rum'}],
#      'syllables_count': 5,
#      'word': 'jūdiciōrum'},
#     {'index': 55,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'quī'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'runt'}],
#      'syllables_count': 3,
#      'word': 'requīrunt'}]},
#   {'contains_abbrev': False,
#    'contains_numeral': False,
#    'plain_text_sentence': ' nōn enim corōna cōnsessus vester cīnctus est, ut solēbat',
#    'structured_sentence': [{'index': 0,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'nōn'}],
#      'syllables_count': 1,
#      'word': 'nōn'},
#     {'index': 1,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'en'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'im'}],
#      'syllables_count': 2,
#      'word': 'enim'},
#     {'index': 2,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'co'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'na'}],
#      'syllables_count': 3,
#      'word': 'corōna'},
#     {'index': 3,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'cōn'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ses'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'sus'}],
#      'syllables_count': 3,
#      'word': 'cōnsessus'},
#     {'index': 4,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ves'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ter'}],
#      'syllables_count': 2,
#      'word': 'vester'},
#     {'index': 5,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'cīn'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ctus'}],
#      'syllables_count': 2,
#      'word': 'cīnctus'},
#     {'index': 6,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'est'}],
#      'syllables_count': 1,
#      'word': 'est,'},
#     {'index': 7,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ut'}],
#      'syllables_count': 1,
#      'word': 'ut'},
#     {'index': 8,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'so'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'lē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'bat'}],
#      'syllables_count': 3,
#      'word': 'solēbat'}]},
#   {'contains_abbrev': False,
#    'contains_numeral': False,
#    'plain_text_sentence': ' nōn ūsitātā frequentiā stīpātī sumus',
#    'structured_sentence': [{'index': 0,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'nōn'}],
#      'syllables_count': 1,
#      'word': 'nōn'},
#     {'index': 1,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'si'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tā'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'tā'}],
#      'syllables_count': 4,
#      'word': 'ūsitātā'},
#     {'index': 2,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'fre'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'quen'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ti'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, 'sest'),
#        'syllable': 'ā'}],
#      'syllables_count': 4,
#      'word': 'frequentiā'},
#     {'index': 3,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'stī'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'pā'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tī'}],
#      'syllables_count': 3,
#      'word': 'stīpātī'},
#     {'index': 4,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'su'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'mus'}],
#      'syllables_count': 2,
#      'word': 'sumus'}]},
#   {'contains_abbrev': False,
#    'contains_numeral': False,
#    'plain_text_sentence': ' nōn illa praesidia quae prō templīs omnibus cernitis, etsī contrā vim conlocāta sunt, nōn adferunt tamen ōrātōrī terrōris aliquid, ut in forō et in jūdiciō, quamquam praesidiīs salūtāribus et necessāriīs saeptī sumus, tamen nē nōn timēre quidem sine aliquō timōre possīmus',
#    'structured_sentence': [{'index': 0,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'nōn'}],
#      'syllables_count': 1,
#      'word': 'nōn'},
#     {'index': 1,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'il'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, 'mute+liquid'),
#        'syllable': 'la'}],
#      'syllables_count': 2,
#      'word': 'illa'},
#     {'index': 2,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'prae'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'si'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'a'}],
#      'syllables_count': 4,
#      'word': 'praesidia'},
#     {'index': 3,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, 'mute+liquid'),
#        'syllable': 'quae'}],
#      'syllables_count': 1,
#      'word': 'quae'},
#     {'index': 4,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'prō'}],
#      'syllables_count': 1,
#      'word': 'prō'},
#     {'index': 5,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tem'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'plīs'}],
#      'syllables_count': 2,
#      'word': 'templīs'},
#     {'index': 6,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'om'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ni'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'bus'}],
#      'syllables_count': 3,
#      'word': 'omnibus'},
#     {'index': 7,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'cer'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ni'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'tis'}],
#      'syllables_count': 3,
#      'word': 'cernitis,'},
#     {'index': 8,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'et'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'sī'}],
#      'syllables_count': 2,
#      'word': 'etsī'},
#     {'index': 9,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'con'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'trā'}],
#      'syllables_count': 2,
#      'word': 'contrā'},
#     {'index': 10,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'vim'}],
#      'syllables_count': 1,
#      'word': 'vim'},
#     {'index': 11,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'con'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'lo'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'cā'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ta'}],
#      'syllables_count': 4,
#      'word': 'conlocāta'},
#     {'index': 12,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'sunt'}],
#      'syllables_count': 1,
#      'word': 'sunt,'},
#     {'index': 13,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'nōn'}],
#      'syllables_count': 1,
#      'word': 'nōn'},
#     {'index': 14,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ad'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'fe'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'runt'}],
#      'syllables_count': 3,
#      'word': 'adferunt'},
#     {'index': 15,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ta'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'men'}],
#      'syllables_count': 2,
#      'word': 'tamen'},
#     {'index': 16,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rā'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rī'}],
#      'syllables_count': 4,
#      'word': 'ōrātōrī'},
#     {'index': 17,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ter'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ris'}],
#      'syllables_count': 3,
#      'word': 'terrōris'},
#     {'index': 18,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'a'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'li'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'quid'}],
#      'syllables_count': 3,
#      'word': 'aliquid,'},
#     {'index': 19,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ut'}],
#      'syllables_count': 1,
#      'word': 'ut'},
#     {'index': 20,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'in'}],
#      'syllables_count': 1,
#      'word': 'in'},
#     {'index': 21,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'fo'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rō'}],
#      'syllables_count': 2,
#      'word': 'forō'},
#     {'index': 22,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'et'}],
#      'syllables_count': 1,
#      'word': 'et'},
#     {'index': 23,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'in'}],
#      'syllables_count': 1,
#      'word': 'in'},
#     {'index': 24,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'jū'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ci'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ō'}],
#      'syllables_count': 4,
#      'word': 'jūdiciō,'},
#     {'index': 25,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'quam'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
# ...
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'lī'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'us'}],
#      'syllables_count': 3,
#      'word': 'illīus'},
#     {'index': 2,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'īn'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'si'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, 'mute+liquid'),
#        'syllable': 'ae'}],
#      'syllables_count': 4,
#      'word': 'īnsidiae'},
#     {'index': 3,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'clā'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ri'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'rēs'}],
#      'syllables_count': 4,
#      'word': 'clāriōrēs'},
#     {'index': 4,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'hāc'}],
#      'syllables_count': 1,
#      'word': 'hāc'},
#     {'index': 5,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'lū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ce'}],
#      'syllables_count': 2,
#      'word': 'lūce'},
#     {'index': 6,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'fu'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'e'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'rint'}],
#      'syllables_count': 3,
#      'word': 'fuerint,'},
#     {'index': 7,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tum'}],
#      'syllables_count': 1,
#      'word': 'tum'},
#     {'index': 8,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'dē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ni'},
#       {'accented': False,
#        'elide': (True, 'weak'),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'que'}],
#      'syllables_count': 3,
#      'word': 'dēnique'},
#     {'index': 9,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ob'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, 'mute+liquid'),
#        'syllable': 'se'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'crā'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'bō'}],
#      'syllables_count': 4,
#      'word': 'obsecrābō'},
#     {'index': 10,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ob'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tes'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tā'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'bor'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 4,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'que'}],
#      'syllables_count': 5,
#      'word': 'obtestāborque'},
#     {'index': 11,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'vōs'}],
#      'syllables_count': 1,
#      'word': 'vōs,'},
#     {'index': 12,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'jū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'di'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'cēs'}],
#      'syllables_count': 3,
#      'word': 'jūdicēs,'},
#     {'index': 13,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'sī'}],
#      'syllables_count': 1,
#      'word': 'sī'},
#     {'index': 14,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'cē'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'te'},
#       {'accented': False,
#        'elide': (True, 'weak'),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ra'}],
#      'syllables_count': 3,
#      'word': 'cētera'},
#     {'index': 15,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'ā'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mī'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'si'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'mus'}],
#      'syllables_count': 4,
#      'word': 'āmīsimus,'},
#     {'index': 16,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'hoc'}],
#      'syllables_count': 1,
#      'word': 'hoc'},
#     {'index': 17,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'nō'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'bīs'}],
#      'syllables_count': 2,
#      'word': 'nōbīs'},
#     {'index': 18,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'sal'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'tem'}],
#      'syllables_count': 2,
#      'word': 'saltem'},
#     {'index': 19,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'ut'}],
#      'syllables_count': 1,
#      'word': 'ut'},
#     {'index': 20,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'lin'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'quā'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'tur'}],
#      'syllables_count': 4,
#      'word': 'relinquātur,'},
#     {'index': 21,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'vī'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'tam'}],
#      'syllables_count': 2,
#      'word': 'vītam'},
#     {'index': 22,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ab'}],
#      'syllables_count': 1,
#      'word': 'ab'},
#     {'index': 23,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'in'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'i'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'mī'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'cō'},
#       {'accented': False,
#        'elide': (True, 'strong'),
#        'index': 4,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'rum'}],
#      'syllables_count': 5,
#      'word': 'inimīcōrum'},
#     {'index': 24,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'au'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'dā'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ci'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'a'}],
#      'syllables_count': 4,
#      'word': 'audācia'},
#     {'index': 25,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'tē'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (True, None),
#        'syllable': 'līs'},
#       {'accented': False,
#        'elide': (True, 'weak'),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'que'}],
#      'syllables_count': 3,
#      'word': 'tēlīsque'},
#     {'index': 26,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ut'}],
#      'syllables_count': 1,
#      'word': 'ut'},
#     {'index': 27,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'im'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'pū'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ne'}],
#      'syllables_count': 3,
#      'word': 'impūne'},
#     {'index': 28,
#      'syllables': [{'accented': True,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'li'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'ce'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'at'}],
#      'syllables_count': 3,
#      'word': 'liceat'},
#     {'index': 29,
#      'syllables': [{'accented': False,
#        'elide': (False, None),
#        'index': 0,
#        'long_by_nature': True,
#        'long_by_position': (False, None),
#        'syllable': 'dē'},
#       {'accented': True,
#        'elide': (False, None),
#        'index': 1,
#        'long_by_nature': False,
#        'long_by_position': (True, None),
#        'syllable': 'fen'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 2,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 'de'},
#       {'accented': False,
#        'elide': (False, None),
#        'index': 3,
#        'long_by_nature': False,
#        'long_by_position': (False, None),
#        'syllable': 're'}],
#      'syllables_count': 4,
#      'word': 'dēfendere'}]},
#   {'contains_abbrev': False,
#    'contains_numeral': False,
#    'plain_text_sentence': ' ',
#    'structured_sentence': []}],
#  'title': 'No Title'}

# %%
not_elided = "sī quem habētis dēpōnite."
preprocessor = Preprocessor(text=not_elided)
analysis = Analyze()
tokens = preprocessor.tokenize()
analysis.get_rhythms(tokens)
# Out:
# [('sī quem habētis dēpōnite', '----x'), ('', 'x')]
